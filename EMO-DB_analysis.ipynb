# %%
from IPython.display import clear_output

# %%
# !wget -O EMO-DB.zip http://emodb.bilderbar.info/download/download.zip
# Out:
# --2024-10-22 12:15:43--  http://emodb.bilderbar.info/download/download.zip
# Resolving emodb.bilderbar.info (emodb.bilderbar.info)... 85.13.147.80
# Connecting to emodb.bilderbar.info (emodb.bilderbar.info)|85.13.147.80|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40567066 (39M) [application/zip]
# Saving to: ‘EMO-DB.zip’
#
# EMO-DB.zip          100%[===================>]  38.69M  1.18MB/s    in 33s
#
# 2024-10-22 12:16:16 (1.18 MB/s) - ‘EMO-DB.zip’ saved [40567066/40567066]

# %%
# !git clone https://github.com/karanm21/EE798R_term_project.git

# !mv /content/EMO-DB.zip /content/EE798R_term_project/data
# !unzip /content/EE798R_term_project/data/EMO-DB.zip -d /content/EE798R_term_project/data/EMO-DB

clear_output()

# %%
import os

os.chdir("/content/EE798R_term_project")

# %%
# !python train.py -dn "EMO-DB" -id 3 -at "all" -ln "cross_entropy" -v 0 -it "mfcc" -c "ram" -m true
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729599384.787960    1348 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729599385.654214    1348 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729599385.654506    1348 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
# !python train.py -dn "EMO-DB" -id 3 -at "all" -ln "focal" -v 1 -it "mfcc" -c "disk" -m false
